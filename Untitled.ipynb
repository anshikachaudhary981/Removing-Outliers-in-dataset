# %%
# We have a cars dataset in which columns have some outliers 
# We have to remive it to remove those data which can affect our predictions

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
for name, _, filenames in os.walk(r'C:\Users\harsh\Desktop\Untitled Folder\CARS'):
    for filename in filenames:
        print(os.path.join(name, filename))
# Out:
# C:\Users\harsh\Desktop\Untitled Folder\CARS\Untitled.ipynb
# C:\Users\harsh\Desktop\Untitled Folder\CARS\US_CARS.csv
# C:\Users\harsh\Desktop\Untitled Folder\CARS\.ipynb_checkpoints\Untitled-checkpoint.ipynb

# %%
cars=pd.read_csv("US_CARS.csv")

# %%
cars
# Out:
#       Unnamed: 0  price      brand    model  year   title_status  mileage  \
# 0              0   6300     toyota  cruiser  2008  clean vehicle   274117
# 1              1   2899       ford       se  2011  clean vehicle   190552
# 2              2   5350      dodge      mpv  2018  clean vehicle    39590
# 3              3  25000       ford     door  2014  clean vehicle    64146
# 4              4  27700  chevrolet     1500  2018  clean vehicle     6654
# ...          ...    ...        ...      ...   ...            ...      ...
# 2494        2494   7800     nissan    versa  2019  clean vehicle    23609
# 2495        2495   9200     nissan    versa  2018  clean vehicle    34553
# 2496        2496   9200     nissan    versa  2018  clean vehicle    31594
# 2497        2497   9200     nissan    versa  2018  clean vehicle    32557
# 2498        2498   9200     nissan    versa  2018  clean vehicle    31371
#
#        color                  vin        lot       state country  \
# ...

# %%
#we are going to remove unnamed column
cars.drop(cars.columns[cars.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)

# %%
cars.head()
# Out:
#    price      brand    model  year   title_status  mileage   color  \
# 0   6300     toyota  cruiser  2008  clean vehicle   274117   black
# 1   2899       ford       se  2011  clean vehicle   190552  silver
# 2   5350      dodge      mpv  2018  clean vehicle    39590  silver
# 3  25000       ford     door  2014  clean vehicle    64146    blue
# 4  27700  chevrolet     1500  2018  clean vehicle     6654     red
#
#                    vin        lot       state country      condition
# 0    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4    3gcpcrec2jg473991  167763266     florida     usa  22 hours left

# %%
cars.isnull().sum()
#there are no values
# Out:
# price           0
# brand           0
# model           0
# year            0
# title_status    0
# mileage         0
# color           0
# vin             0
# lot             0
# state           0
# country         0
# condition       0
# dtype: int64

# %%
cars["country"].unique()
# Out:
# array([' usa', ' canada'], dtype=object)

# %%
cars.shape
# Out:
# (2499, 12)

# %%
plt.boxplot(cars['price'])

cars.describe()


# we can see that there are outliers beacuese 
# so we have to remove them
# Out:
#               price         year       mileage           lot
# count   2499.000000  2499.000000  2.499000e+03  2.499000e+03
# mean   18767.671469  2016.714286  5.229869e+04  1.676914e+08
# std    12116.094936     3.442656  5.970552e+04  2.038772e+05
# min        0.000000  1973.000000  0.000000e+00  1.593488e+08
# 25%    10200.000000  2016.000000  2.146650e+04  1.676253e+08
# 50%    16900.000000  2018.000000  3.536500e+04  1.677451e+08
# 75%    25555.500000  2019.000000  6.347250e+04  1.677798e+08
# max    84900.000000  2020.000000  1.017936e+06  1.678055e+08

# %%
#removing outlier from z score formula
outlier=[]
def remove(data):
    threshold=3
    mean=np.mean(data)
    std=np.std(data)
    
    for i in data:
        z_score=(i - mean)/std
        if np.abs(z_score)>threshold:
            outlier.append(i)
    return outlier

# %%
out=remove(cars['price'])
out
# Out:
# [67000,
#  61200,
#  58500,
#  55600,
#  84900,
#  62000,
#  63200,
#  65500,
#  56700,
#  65200,
#  63000,
#  70000,
#  56200,
#  57700,
#  74000,
#  60200,
#  60000,
#  63000,
#  58500,
#  56500,
#  56500,
#  59975,
#  59975,
#  59900,
#  56000,
#  67000,
#  61200,
#  58500,
#  55600,
#  84900,
#  62000,
#  63200,
#  65500,
#  56700,
#  65200,
#  63000,
#  70000,
#  56200,
#  57700,
#  74000,
#  60200,
#  60000,
#  63000,
#  58500,
#  56500,
#  56500,
#  59975,
#  59975,
#  59900,
#  56000,
#  67000,
#  61200,
#  58500,
#  55600,
#  84900,
#  62000,
#  63200,
#  65500,
#  56700,
#  65200,
#  63000,
#  70000,
#  56200,
#  57700,
#  74000,
#  60200,
#  60000,
#  63000,
#  58500,
#  56500,
#  56500,
#  59975,
#  59975,
#  59900,
#  56000,
#  67000,
#  61200,
#  58500,
#  55600,
#  84900,
#  62000,
#  63200,
#  65500,
#  56700,
#  65200,
#  63000,
#  70000,
#  56200,
#  57700,
#  74000,
#  60200,
#  60000,
#  63000,
#  58500,
#  56500,
#  56500,
#  59975,
#  59975,
#  59900,
#  56000]

# %%
cars1=np.min(out)
cars1
# Out:
# 55600

# %%
values=[]
def value(pp):
    for y in pp:
        if y <55600:
            values.append(y)
    return values

# %%
a=value(cars['price'])
np.max(a)
# Out:
# 55000

# %%
#After removing outliers 
# we are using our function because our data has remaining outliers
out2=remove(a)
value2=value(out2)
value2
plt.boxplot(value2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xd435bf0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0xd435470>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0xd435c30>],
#  'medians': [<matplotlib.lines.Line2D at 0xd435eb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0xdb14fd0>],
#  'means': []}

# %%
# we can see that we have some outliers also after removing 2 times
out3=remove(value2)
out3
# Out:
# [67000,
#  61200,
#  58500,
#  55600,
#  84900,
#  62000,
#  63200,
#  65500,
#  56700,
#  65200,
#  63000,
#  70000,
#  56200,
#  57700,
#  74000,
#  60200,
#  60000,
#  63000,
#  58500,
#  56500,
#  56500,
#  59975,
#  59975,
#  59900,
#  56000,
#  67000,
#  61200,
#  58500,
#  55600,
#  84900,
#  62000,
#  63200,
#  65500,
#  56700,
#  65200,
#  63000,
#  70000,
#  56200,
#  57700,
#  74000,
#  60200,
#  60000,
#  63000,
#  58500,
#  56500,
#  56500,
#  59975,
#  59975,
#  59900,
#  56000,
#  67000,
#  61200,
#  58500,
#  55600,
#  84900,
#  62000,
#  63200,
#  65500,
#  56700,
#  65200,
#  63000,
#  70000,
#  56200,
#  57700,
#  74000,
#  60200,
#  60000,
#  63000,
#  58500,
#  56500,
#  56500,
#  59975,
#  59975,
#  59900,
#  56000,
#  67000,
#  61200,
#  58500,
#  55600,
#  84900,
#  62000,
#  63200,
#  65500,
#  56700,
#  65200,
#  63000,
#  70000,
#  56200,
#  57700,
#  74000,
#  60200,
#  60000,
#  63000,
#  58500,
#  56500,
#  56500,
#  59975,
#  59975,
#  59900,
#  56000,
# ...

# %%
value3=value(out3)
value3
# Out:
# [6300,
#  2899,
#  5350,
#  25000,
#  27700,
#  5700,
#  7300,
#  13350,
#  14600,
#  5250,
#  10400,
#  12920,
#  31900,
#  5430,
#  20700,
#  12710,
#  5200,
#  16500,
#  5210,
#  38100,
#  12520,
#  7300,
#  15000,
#  6180,
#  20800,
#  11900,
#  21500,
#  12000,
#  4190,
#  13000,
#  12710,
#  18500,
#  29800,
#  5330,
#  13000,
#  11900,
#  16600,
#  19200,
#  7320,
#  7000,
#  12710,
#  16600,
#  30500,
#  6330,
#  55000,
#  12520,
#  16200,
#  19000,
#  5580,
#  54000,
#  12710,
#  16000,
#  27000,
#  7760,
#  19600,
#  12920,
#  20000,
#  18100,
#  23000,
#  18500,
#  13490,
#  20700,
#  17800,
#  6650,
#  29100,
#  12710,
#  21100,
#  18600,
#  4340,
#  19300,
#  12780,
#  15800,
#  29400,
#  4430,
#  19400,
#  12520,
#  15900,
#  26400,
#  4140,
#  18300,
#  12520,
#  17900,
#  18300,
#  4640,
#  24000,
#  13200,
#  18000,
#  14900,
#  4140,
#  11500,
#  9110,
#  7350,
#  24500,
#  9300,
#  39800,
#  53500,
#  15110,
#  34000,
#  26502,
#  5990,
#  13600,
#  23605,
# ...

# %%
plt.boxplot(value3)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xddb06d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0xddb0cb0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0xddb06b0>],
#  'medians': [<matplotlib.lines.Line2D at 0xddbb410>],
#  'fliers': [<matplotlib.lines.Line2D at 0xddbb630>],
#  'means': []}

# %%
# NOW we succesfully removed all the outliers in price column
#! we have to apply same as it in all important columns
